# %% [markdown]
# # What
# 分类任务，支持两种模式
# 1. Folder模式，需要输入`train`, `valid`两个测试集对应的目录。`labels.txt`，需要训练的label，里面每个类别一行。
# 2. List模式，需要输入`train`, `valid`两个测试集对应的训练文件，每行一个样本。`labels.txt`是可选参数，里面每个类别一行。`data_pattern`一个通用的目录，与train、val中的第一列进行拼接。

# %% [markdown]
# ### 支持的模型名称
#
# 模型名称替换代码中的 `model_name`变量的值。
#
# | **模型系列** | **模型名称**                                                 |
# | ------------ | ------------------------------------------------------------ |
# | AlexNet      | alexnet                                                      |
# | VGG          | vgg11, vgg11_bn, vgg13, vgg13_bn, vgg16, vgg16_bn, vgg19_bn, vgg19 |
# | ResNet       | resnet18, resnet34, resnet50, resnet101, resnet152, resnext50_32x4d, resnext101_32x8d, wide_resnet50_2, wide_resnet101_2 |
# | DenseNet     | densenet121, densenet169, densenet201, densenet161           |
# | Inception    | googlenet, inception_v3                                      |
# | SqueezeNet   | squeezenet1_0, squeezenet1_1                                 |
# | ShuffleNetV2 | shufflenet_v2_x2_0, shufflenet_v2_x0_5, shufflenet_v2_x1_0, shufflenet_v2_x1_5 |
# | MobileNet    | mobilenet_v2, mobilenet_v3_large, mobilenet_v3_small         |
# | MNASNet      | mnasnet0_5, mnasnet0_75, mnasnet1_0, mnasnet1_3              |
# | ViT       | ViT, SimpleViT, Crossformer, TwinsSVT|
#
# ![](http://medai.icu/storage/attachments/2023/10/10/RHd9eH5U67VsOP8vqyNyBD5nGYREejkAKx3Jw16X.)

# %% [markdown]
# ### List模式
#
# 在Onekey中List模式一般是采用labelme标注出来的结果，如果要使用自己的数据应用List模式，需要根据自己的实际情况对数据进行处理。
#
# * `train.txt`，训练数据列表，中间用\t（Tab水平制表符）进行分割。
# * `val.txt`，验证数据列表，中间用\t（Tab水平制表符）进行分割。
# * `labels.txt`，label的集合，表明训练数据多少标签。
# * `data_pattern`参数，所有数据存在的目录的公共前缀，如果`train.txt`,`val.txt`文件里面存放的是绝对路径，`data_pattern`设置为None即可。

# %%
# import os
# from onekey_algo.classification.run_classification import main as clf_main
# from collections import namedtuple
# from onekey_algo import get_param_in_cwd

# # 设置参数
# train_f = get_param_in_cwd('train_file') or 'split_info/train-RND-0.txt'
# val_f = get_param_in_cwd('val_file') or 'split_info/val-RND-0.txt'
# labels_f = 'labels.txt'
# data_pattern =  get_param_in_cwd('data_pattern')

# params = dict(train=train_f,
#               valid=val_f,
#               labels_file=labels_f,
#               data_pattern=data_pattern,
#               j=0,
#               max2use=None,
#               val_max2use=None,
#               batch_balance=False,
#               normalize_method='imagenet',
#               model_name=get_param_in_cwd('model_name', 'resnet50'),
#               vit_settings = {'patch_size': 64, 'dim': 1024, 'depth': 6, 'heads': 16, 'mlp_dim': 768},
#               gpus=[0],
#               batch_size=32,
#               epochs=get_param_in_cwd('epoch', 50),
#               init_lr=0.01,
#               optimizer='sgd',
#               retrain=None,
#               model_root=get_param_in_cwd('model_root', 'dl_models'),
#               add_date=False,
#               iters_start=0,
#               iters_verbose=1,
#               save_per_epoch=False,
#               pretrained=True)
# # 训练模型
# Args = namedtuple("Args", params)
# clf_main(Args(**params))

# %%
import os
from onekey_algo.classification.run_classification import main as clf_main
from collections import namedtuple
from onekey_algo import get_param_in_cwd

# 设置参数
train_f = get_param_in_cwd('train_file') or 'split_info/train-RND-0.txt'
val_f = get_param_in_cwd('val_file') or 'split_info/val-RND-0.txt'
labels_f = 'labels.txt'
data_pattern =  get_param_in_cwd('data_pattern')

# 循环10次
for i in range(1):
    # 为每次循环创建不同的输出文件夹
    output_folder = f"experiment"
    os.makedirs(output_folder, exist_ok=True)

    for model_name in ['ViT']:
        params = dict(train=train_f,
              valid=val_f,
              labels_file=labels_f,
              data_pattern=data_pattern,
              j=0,
              max2use=None,
              val_max2use=None,
              batch_balance=False,
              normalize_method='imagenet',
              model_name=model_name,
              vit_settings = {'patch_size': 64, 'dim': 1024, 'depth': 6, 'heads': 16, 'mlp_dim': 768},
              gpus=[0],
              batch_size=32,
              epochs=get_param_in_cwd('epoch', 50),
              init_lr=0.01,
              optimizer='sgd',
              retrain=None,
              model_root=os.path.join(get_param_in_cwd('model_root', 'dl_models'), output_folder, f"b1-try-{i+1}"),
              add_date=False,
              iters_start=0,
              iters_verbose=1,
              save_per_epoch=False,
              pretrained=True)
       
        # 训练模型
        Args = namedtuple("Args", params)
        clf_main(Args(**params))
# Out:
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>: 662]	INFO	WE RECOMMEND YOU USE SPECIFY dataset_name LIKE list for ListDataset OR folder for FolderDataset.
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>:  83]	INFO	Parsing record file E:\\111thymus\\thymus_habitat\\dl410\\2_73 - 副本\\train-RND-2.txt
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>:  86]	INFO		Checking file exists in E:\\111thymus\\thymus_habitat\\dl410\\2_73 - 副本\\train-RND-2.txt
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>: 673]	INFO	We infer your kwargs to be <class 'onekey_algo.datasets.ClassificationDataset.ListDataset'>.
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>: 662]	INFO	WE RECOMMEND YOU USE SPECIFY dataset_name LIKE list for ListDataset OR folder for FolderDataset.
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>:  83]	INFO	Parsing record file E:\\111thymus\\thymus_habitat\\dl410\\2_73 - 副本\\val-RND-2.txt
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>:  86]	INFO		Checking file exists in E:\\111thymus\\thymus_habitat\\dl410\\2_73 - 副本\\val-RND-2.txt
# [2025-05-08 19:33:03 - <frozen onekey_algo.datasets.ClassificationDataset>: 673]	INFO	We infer your kwargs to be <class 'onekey_algo.datasets.ClassificationDataset.ListDataset'>.
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO	Train:Dataset is ListDataset
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Number of samples: 429
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Root location: E:\\111thymus\\thymus_habitat\\dl410\\2Dimages
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Labels file is stored in E:\111thymus\thymus_habitat\sol11. 深度（迁移）学习-单（多）中心-组学特征-融合-临床\labels.txt
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO	Valid:Dataset is ListDataset
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Number of samples: 193
# [2025-05-08 19:33:03 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Root location: E:\\111thymus\\thymus_habitat\\dl410\\2Dimages
# [2025-05-08 19:33:03 - <frozen onekey_algo.classification.run_classification>: 323]	INFO	Creating model ViT...
# [2025-05-08 19:33:03 - vit.py:  93]	INFO	正在使用 ViT模型，具体参数为：images_size=256, patch_size=64, num_classes=2, dim=1024, depth=6, heads=16, mlp_dim=768
# [2025-05-08 19:33:04 - <frozen onekey_algo.classification.run_classification>: 370]	INFO	Start training...
# [2025-05-08 19:33:04 - <frozen onekey_algo.utils.common>: 113]	INFO	Successfully delete directory dl_models\experiment\b1-try-1\ViT\train
# [2025-05-08 19:33:04 - <frozen onekey_algo.utils.common>: 113]	INFO	Successfully delete directory dl_models\experiment\b1-try-1\ViT\valid
# [2025-05-08 19:33:04 - <frozen onekey_algo.utils.common>: 113]	INFO	Successfully delete directory dl_models\experiment\b1-try-1\ViT\viz
# [2025-05-08 19:33:05 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.075,1	LR: 0.009964	Loss: 0.639	Acc: 68.7500	 Speed: 20.82 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:05 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.149,2	LR: 0.009855	Loss: 1.021	Acc: 68.7500	 Speed: 117.64 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:06 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.224,3	LR: 0.009675	Loss: 3.946	Acc: 34.3750	 Speed: 120.15 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:06 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.298,4	LR: 0.009427	Loss: 3.231	Acc: 75.0000	 Speed: 121.66 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:06 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.373,5	LR: 0.009115	Loss: 2.168	Acc: 68.7500	 Speed: 114.66 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:06 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.448,6	LR: 0.008743	Loss: 0.880	Acc: 43.7500	 Speed: 120.72 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:07 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.522,7	LR: 0.008316	Loss: 1.136	Acc: 81.2500	 Speed: 113.25 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:07 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.597,8	LR: 0.007840	Loss: 0.761	Acc: 68.7500	 Speed: 114.16 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:07 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.671,9	LR: 0.007324	Loss: 1.603	Acc: 31.2500	 Speed: 106.58 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:08 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.746,10	LR: 0.006773	Loss: 1.831	Acc: 81.2500	 Speed: 124.39 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:08 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.821,11	LR: 0.006197	Loss: 2.141	Acc: 65.6250	 Speed: 124.97 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:08 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.895,12	LR: 0.005603	Loss: 0.680	Acc: 59.3750	 Speed: 120.07 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:08 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.970,13	LR: 0.005000	Loss: 0.685	Acc: 53.1250	 Speed: 109.23 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:09 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.044,14	LR: 0.004397	Loss: 1.283	Acc: 69.2308	 Speed: 111.04 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:10 - <frozen onekey_algo.classification.run_classification>: 251]	INFO	Phase: valid	acc: 67.358	Speed: 126.2965img/s	Time: 1.53s
# [2025-05-08 19:33:10 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.119,15	LR: 0.003803	Loss: 0.703	Acc: 56.2500	 Speed: 17.94 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:11 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.193,16	LR: 0.003227	Loss: 0.795	Acc: 34.3750	 Speed: 105.06 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:11 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.268,17	LR: 0.002676	Loss: 0.425	Acc: 84.3750	 Speed: 106.52 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:11 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.343,18	LR: 0.002160	Loss: 0.587	Acc: 75.0000	 Speed: 111.06 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:12 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.417,19	LR: 0.001684	Loss: 0.566	Acc: 75.0000	 Speed: 102.39 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:12 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.492,20	LR: 0.001257	Loss: 0.746	Acc: 56.2500	 Speed: 83.56 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:12 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.566,21	LR: 0.000885	Loss: 0.635	Acc: 71.8750	 Speed: 93.70 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:13 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.641,22	LR: 0.000573	Loss: 0.594	Acc: 71.8750	 Speed: 94.23 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:13 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.716,23	LR: 0.000325	Loss: 0.526	Acc: 81.2500	 Speed: 82.15 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:13 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.790,24	LR: 0.000145	Loss: 0.647	Acc: 65.6250	 Speed: 88.31 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.865,25	LR: 0.000036	Loss: 0.569	Acc: 75.0000	 Speed: 91.35 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 1.939,26	LR: 0.000000	Loss: 0.740	Acc: 56.2500	 Speed: 84.76 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 2.014,27	LR: 0.000036	Loss: 0.591	Acc: 71.8750	 Speed: 84.80 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:15 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 2.089,28	LR: 0.000145	Loss: 0.535	Acc: 76.9231	 Speed: 68.97 img/s	Time: 0hrs:0min
# [2025-05-08 19:33:16 - <frozen onekey_algo.classification.run_classification>: 251]	INFO	Phase: valid	acc: 67.358	Speed: 112.5349img/s	Time: 1.72s
# [2025-05-08 19:33:17 - <frozen onekey_algo.classification.run_classification>: 387]	INFO	Done for training. Best metric is 67.35751295336787@1 epoch. Average for last 5 iters is 67.35751295336787

# %% [markdown]
# # Grid-Search 方法参考

# %%
# for cv in range(10):
#     train_f = rf'C:\Users\onekey\Desktop\202231126\split_info\train-RND-{cv}.txt'
#     val_f = rf'C:\Users\onekey\Desktop\202231126\split_info\val-RND-{cv}.txt'
#     for model_name in ['resnet50', 'resnet101']:
#         for init_lr in [0.1, 0.05, 0.001]
#         params = dict(train=train_f,
#                       valid=val_f,
#                       labels_file=labels_f,
#                       data_pattern=data_pattern,
#                       j=4,
#                       max2use=None,
#                       val_max2use=None,
#                       batch_balance=False,
#                       normalize_method='imagenet',
#                       model_name=model_name,
#                       vit_settings = {'patch_size': 64, 'dim': 1024, 'depth': 6, 'heads': 16, 'mlp_dim': 768},
#                       gpus=[0],
#                       batch_size=32,
#                       epochs=1,
#                       init_lr=0.01,
#                       optimizer='sgd',
#                       retrain=None,
#                       model_root='dl_models',
#                       add_date=False,
#                       iters_start=0,
#                       iters_verbose=1,
#                       save_per_epoch=False,
#                       pretrained=True)
#         # 训练模型
#         Args = namedtuple("Args", params)
#         clf_main(Args(**params))
